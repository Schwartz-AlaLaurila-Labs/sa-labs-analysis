% %%
tbUseProject('sa-labs-analysis', 'online', false);

% %%
clear;
project = createAnalysisProject('Example-LightStep-Analysis', 'experiments', '20170407')
% Out:
% OfflineAnalaysisManager.initializeProject 2017-05-10 11:48:29,889 INFO     project [ Example-LightStep-Analysis ] initialized
%
% project =
%
%   AnalysisProject with properties:
%
%               identifier: 'Example-LightStep-Analysis'
%              description: 'Hope it will be defined later !'
%           experimentList: {'20170407'}
%           cellDataIdList: {'20170407Dc1'  '20170407Dc2'  '20170407Dc3'  '20170407Dc4'}
%             analysisDate: '20170509'
%     analysisResultIdList: {1×4 cell}
%              performedBy: 'narayas2'
%                     file: 'C:\Users\narayas2\data\analysis\Projects\Example-LightStep-Analysis\project.json'

% %%
%% Create Analysis structure

analysisPreset = struct();
analysisPreset.type = 'analysis-type-1';
analysisPreset.buildTreeBy = {'displayName', 'chan1Mode, chan2Mode, chan3Mode, chan4Mode'};
analysisPreset.chan1Mode.splitValue = {'Cell attached'};
analysisPreset.chan2Mode.splitValue = {'Cell attached'};
analysisPreset.chan3Mode.splitValue = {'Cell attached'};
analysisPreset.chan4Mode.splitValue = {'Cell attached'};

% %%
%% Build Analysis structure

buildAnalysis('Example-LightStep-Analysis', analysisPreset)
% Out:
% OfflineAnalaysisManager.initializeProject 2017-05-10 11:48:40,057 INFO     project [ Example-LightStep-Analysis ] initialized
% OfflineAnalysis.build 2017-05-10 11:48:40,297 INFO     started building analysis for cell [ 20170407Dc1 ] using  [ analysis-type-1-20170407Dc1 ]
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:41,567 WARNING  No matching split value; [chan2Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:41,730 WARNING  No matching split value; [chan2Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:42,239 WARNING  No matching split value; [chan3Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:42,381 WARNING  No matching split value; [chan3Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:42,957 WARNING  No matching split value; [chan4Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:43,145 WARNING  No matching split value; [chan4Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.build 2017-05-10 11:48:43,866 INFO     End building analysis for cell [ 20170407Dc1 ]
% OfflineAnalysis.build 2017-05-10 11:48:44,242 INFO     started building analysis for cell [ 20170407Dc2 ] using  [ analysis-type-1-20170407Dc2 ]
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:44,920 WARNING  No matching split value; [chan2Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:45,035 WARNING  No matching split value; [chan2Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:45,214 WARNING  No matching split value; [chan2Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:45,501 WARNING  No matching split value; [chan3Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:45,646 WARNING  No matching split value; [chan3Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:45,852 WARNING  No matching split value; [chan3Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:46,144 WARNING  No matching split value; [chan4Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:46,288 WARNING  No matching split value; [chan4Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:46,492 WARNING  No matching split value; [chan4Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.build 2017-05-10 11:48:46,811 INFO     End building analysis for cell [ 20170407Dc2 ]
% OfflineAnalysis.build 2017-05-10 11:48:46,929 INFO     started building analysis for cell [ 20170407Dc3 ] using  [ analysis-type-1-20170407Dc3 ]
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:47,323 WARNING  No matching split value; [chan2Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:47,428 WARNING  No matching split value; [chan2Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:47,545 WARNING  No matching split value; [chan2Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:47,636 WARNING  No matching split value; [chan3Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:47,751 WARNING  No matching split value; [chan3Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:47,868 WARNING  No matching split value; [chan3Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:47,944 WARNING  No matching split value; [chan4Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:48,043 WARNING  No matching split value; [chan4Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:48,134 WARNING  No matching split value; [chan4Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.build 2017-05-10 11:48:48,305 INFO     End building analysis for cell [ 20170407Dc3 ]
% OfflineAnalysis.build 2017-05-10 11:48:48,391 INFO     started building analysis for cell [ 20170407Dc4 ] using  [ analysis-type-1-20170407Dc4 ]
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:48,533 WARNING  No matching split value; [chan2Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:48,627 WARNING  No matching split value; [chan3Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.getSplitValues 2017-05-10 11:48:48,737 WARNING  No matching split value; [chan4Mode =Cell attached ] not found while building the tree
% OfflineAnalysis.build 2017-05-10 11:48:48,848 INFO     End building analysis for cell [ 20170407Dc4 ]
%
% ans =
%
%   OfflineAnalaysisManager with properties:
%
%         analysisDao: [1×1 sa_labs.analysis.dao.AnalysisFolderDao]
%       parserFactory: [1×1 sa_labs.analysis.factory.ParserFactory]
%     analysisFactory: [1×1 sa_labs.analysis.factory.AnalysisFactory]
%                 log: [1×1 logging.logging]

% %%
finder = getFeatureFinder('Example-LightStep-Analysis', 'cellData', 'dc1');
finder.getStructure().tostring()
% Out:
% OfflineAnalaysisManager.initializeProject 2017-05-10 11:49:19,086 INFO     project [ Example-LightStep-Analysis ] initialized
% FeatureTreeBuilder.append 2017-05-10 11:49:19,122 INFO     analysis==analysis-type-1-20170407Dc1 is grafted to parant tree
%
% ans =
%
%               project==Example-LightStep-Analysis (1)
%
%                                  |
%              analysis==analysis-type-1-20170407Dc1 (2)
%               +------------------+--------------+
%               |                                 |
%  displayName==Light Step (3)  displayName==White Noise Flicker (5)
%
%               |                                 |
% chan1Mode==Cell attached (4)      chan1Mode==Cell attached (6)

% %%
finder = getFeatureFinder('Example-LightStep-Analysis');
displayTree(finder)
% Out:
% OfflineAnalaysisManager.initializeProject 2017-05-10 11:49:58,725 INFO     project [ Example-LightStep-Analysis ] initialized
% FeatureTreeBuilder.append 2017-05-10 11:49:58,737 INFO     analysis==analysis-type-1-20170407Dc1 is grafted to parant tree
% FeatureTreeBuilder.append 2017-05-10 11:49:58,742 INFO     analysis==analysis-type-1-20170407Dc2 is grafted to parant tree
% FeatureTreeBuilder.append 2017-05-10 11:49:58,747 INFO     analysis==analysis-type-1-20170407Dc3 is grafted to parant tree
% FeatureTreeBuilder.append 2017-05-10 11:49:58,752 INFO     analysis==analysis-type-1-20170407Dc4 is grafted to parant tree
% Loading customizations in UIExtrasTree.jar
